# %%
import pandas as pd
# %pylab inline
data = pd.read_csv('Intel_CPUs.csv')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data.describe()
# Out:
#        nb_of_Cores  nb_of_Threads  Max_nb_of_Memory_Channels  \
# count  2283.000000    1427.000000                1414.000000
# mean      4.066579       8.728101                   2.615276
# std       6.329884       9.132518                   1.470327
# min       1.000000       1.000000                   1.000000
# 25%       1.000000       4.000000                   2.000000
# 50%       2.000000       4.000000                   2.000000
# 75%       4.000000       8.000000                   3.000000
# max      72.000000      56.000000                  16.000000
#
#        Processor_Graphics_  Support_4k  OpenGL_Support  \
# count                  0.0         0.0             0.0
# mean                   NaN         NaN             NaN
# std                    NaN         NaN             NaN
# min                    NaN         NaN             NaN
# 25%                    NaN         NaN             NaN
# 50%                    NaN         NaN             NaN
# ...

# %%
data.Product_Collection.value_counts()
# Out:
# Legacy Intel® Core™ Processors                   375
# Legacy Intel® Pentium® Processor                 322
# Legacy Intel® Xeon® Processors                   270
# Legacy Intel® Celeron® Processor                 211
# Intel® Xeon® Scalable Processors                  58
# 4th Generation Intel® Core™ i5 Processors         55
# 4th Generation Intel® Core™ i7 Processors         49
# Intel® Xeon® Processor E5 v3 Family               48
# Intel® Xeon® Processor E5 v2 Family               47
# Intel® Xeon® Processor E5 v4 Family               44
# Intel® Xeon® Processor E5 Family                  43
# Legacy Intel Atom® Processors                     43
# Intel® Pentium® Processor G Series                41
# 4th Generation Intel® Core™ i3 Processors         37
# Intel® Atom™ Processor C Series                   32
# Intel® Atom™ Processor Z Series                   30
# Intel® Core™ X-series Processors                  27
# Intel® Xeon® Processor E3 v3 Family               25
# ...

# %%
data.Product_Collection.value_counts().plot(kind='bar')
